# %% [markdown]
# # Eksperimen 3: Tesseract Baseline
#
# Tujuan: Menggunakan Tesseract OCR sebagai baseline/pembanding.
# Tesseract adalah OCR engine klasik yang ringan, namun butuh preprocessing gambar yang baik untuk gambar 'kotor'.

# %%
# !pip install pytesseract
# Pastikan binary Tesseract sudah terinstall di Windows dan masuk PATH

import pytesseract
from PIL import Image

# pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# text = pytesseract.image_to_string(Image.open('sample.jpg'))
# print(text)
