# %% [markdown]
# # Eksperimen 2: PaddleOCR Explore
#
# Tujuan: Mencoba library PaddleOCR sebagai alternatif EasyOCR.
# PaddleOCR dikenal lebih ringan dan akurat untuk beberapa kasus layout dokumen.

# %%
# !pip install paddlepaddle paddleocr
from paddleocr import PaddleOCR, draw_ocr

# Perlu download model bahasanya dulu saat run pertama
ocr = PaddleOCR(use_angle_cls=True, lang='en') 

img_path = 'sample.jpg'
# result = ocr.ocr(img_path, cls=True)
# print(result)
