# %% [markdown]
# # Eksperimen 4: LLM Prompt Engineering
#
# Tujuan: Fokus pada eksperimen prompt untuk memperbaiki teks hasil OCR.
# Kita akan menggunakan dummy text hasil OCR yang jelek, lalu mencoba-coba prompt agar LLM bisa memperbaikinya dengan akurat.

# %%
dirty_ocr_text = "Jawxbxns ay ad@lah l1ma pulun.."

prompts = [
    "Perbaiki typo saja.",
    "Perbaiki typo dan konteks kalimat matematika.",
    "Ekstrak hanya angka dan operator matematika."
]

for p in prompts:
    print(f"Testing prompt: {p} -> Result: ...")
