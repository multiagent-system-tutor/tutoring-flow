# %% [markdown]
# # Eksperimen 1: Eksplorasi OCR + LLM
#
# Notebook ini bertujuan untuk mencoba berbagai kombinasi library OCR dan LLM untuk memperbaiki teks hasil ekstraksi, terutama pada kasus "Gambar Kotor" (coretan, tip-x, tulisan tangan).
#
# ## Daftar Kandidat / Rekomendasi
#
# Berikut adalah daftar kombinasi yang direkomendasikan untuk dicoba:
#
# ### 1. The "Easy" Robust Choice: **EasyOCR + GPT-4o/Gemini**
# - **OCR**: `EasyOCR` (Deep learning based, support 80+ bahasa, bagus untuk teks miring/tulisan tangan).
# - **LLM**: `OpenAI GPT-4o` atau `Google Gemini`.
# - **Pros**: Mudah di-setup, performa OCR sangat bagus out-of-the-box.
# - **Cons**: EasyOCR agak berat di CPU/GPU dibanding Tesseract.
#
# ### 2. The "Open Source" Powerhouse: **PaddleOCR + Llama 3 (via Ollama)**
# - **OCR**: `PaddleOCR` (Sangat populer di industri, ringan dan akurat).
# - **LLM**: `Llama 3` atau `Mistral` via `Ollama` (Local).
# - **Pros**: Gratis total, privasi terjaga, PaddleOCR sering mengalahkan EasyOCR di benchmark.
# - **Cons**: Setup PaddleOCR (terutama di Windows) kadang butuh sedikit effort instalasi dependency.
#
# ### 3. The "Classic" Baseline: **Tesseract + GPT-3.5**
# - **OCR**: `Tesseract` (Google).
# - **LLM**: `GPT-3.5`.
# - **Pros**: Sangat cepat, standar industri lama.
# - **Cons**: Performa buruk pada gambar noise/coretan tanpa pre-processing gambar yang canggih.
#
# ---
#
# ## Persiapan Environment
# Jalankan cell di bawah untuk menginstall library yang diperlukan sesuai pilihan.

# %%
# Install Option 1: EasyOCR (Recommended start)
# !pip install easyocr openai

# Install Option 2: Tesseract (Butuh install binary Tesseract di Windows terpisah)
# !pip install pytesseract

# Install Option 3: PaddleOCR
# !pip install paddlepaddle paddleocr
# Out:
# Requirement already satisfied: easyocr in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (1.7.2)
# Requirement already satisfied: openai in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (2.14.0)
# Requirement already satisfied: torch in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from easyocr) (2.9.1)
# Requirement already satisfied: torchvision>=0.5 in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from easyocr) (0.24.1)
# Requirement already satisfied: opencv-python-headless in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from easyocr) (4.12.0.88)
# Requirement already satisfied: scipy in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from easyocr) (1.16.3)
# Requirement already satisfied: numpy in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from easyocr) (2.2.6)
# Requirement already satisfied: Pillow in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from easyocr) (12.0.0)
# Requirement already satisfied: scikit-image in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from easyocr) (0.26.0)
# Requirement already satisfied: python-bidi in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from easyocr) (0.6.7)
# Requirement already satisfied: PyYAML in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from easyocr) (6.0.2)
# Requirement already satisfied: Shapely in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from easyocr) (2.1.2)
# Requirement already satisfied: pyclipper in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from easyocr) (1.4.0)
# Requirement already satisfied: ninja in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from easyocr) (1.13.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from openai) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from openai) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from openai) (2.12.5)
# Requirement already satisfied: sniffio in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: filelock in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from torch->easyocr) (3.20.1)
# Requirement already satisfied: sympy>=1.13.3 in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from torch->easyocr) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from torch->easyocr) (3.6.1)
# Requirement already satisfied: jinja2 in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from torch->easyocr) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from torch->easyocr) (2025.12.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from sympy>=1.13.3->torch->easyocr) (1.3.0)
# Requirement already satisfied: colorama in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from jinja2->torch->easyocr) (3.0.3)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from scikit-image->easyocr) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from scikit-image->easyocr) (2025.12.20)
# Requirement already satisfied: packaging>=21 in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from scikit-image->easyocr) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in f:\projek dosen\tutoring\tutoring-flow\.venv\lib\site-packages (from scikit-image->easyocr) (0.4)

# %% [markdown]
# ## Percobaan 1: EasyOCR Basic

# %%
import easyocr
import time

# Inisialisasi Reader (Download model di awal agak lama)
# 'en' untuk Inggris, 'id' untuk Indonesia
reader = easyocr.Reader(['en', 'id'], gpu=True) # Set gpu=True jika ada NVIDIA GPU

def run_easyocr(image_path):
    print(f"Processing {image_path}...")
    start_time = time.time()
    
    # detail=0 returns only text list
    result = reader.readtext(image_path, detail=0) 
    
    end_time = time.time()
    text_combined = " ".join(result)
    
    return {
        'time': end_time - start_time,
        'raw_text_list': result,
        'full_text': text_combined
    }

# TODO: Ganti dengan path gambar sampel kamu
# results = run_easyocr('path/to/your/image.jpg')
# print(results)
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %% [markdown]
# ## Percobaan 2: Simulasi LLM Correction
# Anggap kita sudah dapat teks berantakan dari OCR, kita kirim ke LLM.

# %%
# Contoh Mock LLM Call (Ganti dengan API Call asli nanti)
def mock_llm_correction(ocr_text):
    # Prompt logic simulation
    prompt = f"""
    Kamu adalah asisten guru.
    Teks berikut adalah hasil OCR dari jawaban siswa yang mungkin mengandung typo atau pecahan kata.
    Perbaiki teks ini menjadi kalimat yang masuk akal.
    
    OCR Text: {ocr_text}
    """
    print("--- Sending to LLM ---")
    print(prompt)
    print("----------------------")
    
    # Return dummy response
    return "[Ini adalah teks yang sudah diperbaiki oleh LLM]"

# corrected = mock_llm_correction("Jaw b an s y a adal h 5")
# print("Result:", corrected)
